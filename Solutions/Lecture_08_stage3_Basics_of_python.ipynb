# %% [markdown]
# <a href="https://colab.research.google.com/github/mecxlan/Xeven.ai_HTS/blob/main/Lecture_08_stage3_Basics_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hope to Skills - Free AI Course**
# This note book cover the following concepts
# 1. Importing the Libararies in Python
# 2. OpenAI API
# 3. Classification using the OpenAI API

# %% [markdown]
# # **openai**

# %% [markdown]
# ## **Installing of open.ai**
# use the following command to install the open.ai

# %%
# !pip install openai # install openai library for GPT-3 API access
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 3.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing thr openai in the code**

# %%
import openai # import openai library for GPT-3 API access

# %% [markdown]
# ## **Using the open.ai key in the code**
# to generate the key you can go to the link
# https://platform.openai.com/account/api-keys

# %%
openai.api_key = 'sk-6BYWTbIOL****************************H1f5qahC1fL' # set API key from GPT-3 account

# %% [markdown]
# ## **Sentiment Analysis using open.ai api**

# %% [markdown]
# To read the more about the examples on chatgpt
# https://platform.openai.com/examples

# %%
import openai  # import openai library for GPT-3 API access

openai.api_key = 'sk-6BYWTbIOL****************************H1f5qahC1fL' # set API key from GPT-3 account

def Senitment_analysis(text): # define function for sentiment analysis
    messages = [
        {"role": "system", "content": """You are trained to analyze and detect the sentiment of given text.
                                        If you're unsure of an answer, you can say "not sure" and recommend users to review manually."""},
        {"role": "user", "content": f"""Analyze the following text and determine if the sentiment is: positive or negative.
                                        Return answer in single word as either positive or negative: {text}"""}
        ] # set messages for GPT-3 API request

    response = openai.ChatCompletion.create(
                      model="gpt-3.5-turbo",
                      messages=messages,
                      max_tokens=1,
                      n=1,
                      stop=None,
                      temperature=0) # set parameters for GPT-3 API request

    response_text = response.choices[0].message.content.strip().lower() # get response from GPT-3 API request in text format an convert to lowercase, remove spaces, and remove punctuation, etc.

    return response_text

# %%
# calling the function
input = 'I hate fast food' # set input text for sentiment analysis
response = Senitment_analysis(input) # call function for sentiment analysis
print(input,': The Sentiment is', response) # print input text and sentiment analysis result
# Out:
# I hate fast food : The Sentiment is negative

# %% [markdown]
# ## **generating the blog using the open ai api**

# %%
def generate_blog(topic): # define function for blog generation
    messages = [
        {"role": "system", "content": """You are trained to analyze a topic and generate a blog post.
                                        The blog post must contain 1500 to 3000 words (No less than 1500 words)."""},
        {"role": "user", "content": f"""Analyze the topic and generate a blog post. The topic is {topic}
                                        The blog post should contain the following format.
                                        1) Title (Not more than one line).
                                        2) Introduction (Give introducion about the topic)
                                        3) Add an image url relevent to the topic.
                                        4) Add 2/3 subheadings and explain them.
                                        5) Body (should describe the facts and findings)
                                        6) Add an image url relevent to the topic.
                                        7) Add 2/3 subheadings and explain them.
                                        8) General FAQ regarding the topic.
                                        9) Conclusion of the topic. """}
        ] # set messages for GPT-3 API request specifically for blog generation

    response = openai.ChatCompletion.create(
                      model="gpt-3.5-turbo",
                      messages=messages,
                      max_tokens= 3000,
                      n=1,
                      stop=None,
                      temperature=0.5) # set parameters for GPT-3 API request specifically for blog generation

    response_text = response.choices[0].message.content.strip().lower() # get response from GPT-3 API request in text format an convert to lowercase, remove spaces, and remove punctuation, etc.

    return response_text

# %%
user_input ="Machine Learning"
blog = generate_blog(user_input)
print(blog)
# Out:
# title: machine learning: unleashing the power of artificial intelligence
#
# introduction:
# machine learning has become one of the most transformative technologies of our time, revolutionizing industries and shaping the future of artificial intelligence. with its ability to analyze vast amounts of data and make intelligent predictions, machine learning has opened up new possibilities for businesses, healthcare, finance, and many other fields. in this blog post, we will explore the fundamentals of machine learning, its applications, and its impact on society.
#
# ![machine learning](https://example.com/machine-learning-image.jpg)
#
# subheading 1: understanding machine learning
# ...

# %% [markdown]
# # **Sentiment Analysis using the Hugging face pipeline**
# to learn more visit https://huggingface.co/docs/transformers/main_classes/pipelines

# %%
# install tensorflow library
# !pip install tensorflow
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 78.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.5 MB/s eta 0:00:00
# ...

# %%
# Lets build a sentimental analysis using Hugging face pipeline
from transformers import pipeline
classifier = pipeline('sentiment-analysis') # set pipeline for sentiment analysis

classifier('We are very happy to show you the 🤗 Transformers library.')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'label': 'POSITIVE', 'score': 0.9997795224189758}]
